# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize, fmin_slsqp, least_squares

# %%
# %matplotlib notebook

# %%
# -------------------------------------------------------------------------
# Const
# -------------------------------------------------------------------------
nm2m=1852. # 1 nautical mile to meters
kt2ms=nm2m/3600.  # knots to m/s
omega=2*np.pi/(3600.*24.) # angular speed omega=2pi*f(=frequency of earth : 1 cycle per day) 2pi* 1 / day in seconds
rhoa=1.15 #air density  Kg/m^3
radius=6378388 #137. # earth's radius according to WGS 84
deg2m=np.pi*radius/180.  # ds on cicle equals ds=r*dth - dth=pi/180
pn=101000.  # Atmospheric pressure [N/m^2] (101KPa - enviromental pressure)

tetaNE=45. #mean angle [degrees] of North Eastern quadrant
tetaNW=135. #        "              North Western
tetaSW=225. #        "              South West
tetaSE=315. #        "              South East

maxR=500.e3  # maximum radius of TC [m] (500Km)

# %%
kmin=0  # low limit of parameter k (=xn-.5-> k=0-> x=0.5)
kmax=0.25 # upper limit for k (->xn=.65)  WHY?
k0=.1 # initial estimation of holland parameter k

dpmin=10.e2  # minimum value of  pressure drop P_central - P_env(=101kPa).
dpmax=200.e2   # maximum value of  pressure drop P_central - P_env(=101kPa).
dp0=400. #initial estimation of holland parameter dp

rvmaxmin=10.e3  # default minimum value of Rmax[m] 
rmax0=20.e3  # intial estimation for radius of maximum wind [m] (20km)
rmaxmin=5.e3 # intial estimation for radius of maximum wind [m] (5km)

bmin=0.8 # minimum value of holland parameter b
#bmax=2.5
bmax=2.5  # maximum value of holland parameter b
b0=1.2  # initial estimation of holland parameter b

# %%
fk=0.92  # coefficient for going from 1m to 10m in velocities

# %%
radcols=['64ne', '64se', '64sw', '64nw', '50ne', '50se', '50sw', '50nw',
       '34ne', '34se', '34sw', '34nw']

# %%
cols=['w'+ name for name in radcols]

# %%
def hvel(r,dph,bh,rmaxh,kh):
    x=0.5+(r-rmaxh)/(maxR-rmaxh)*kh
    return (bh/rhoa*(rmaxh/r)**bh*dph*np.exp(-(rmaxh/r)**bh))**x

# %%
rh=np.linspace(0.01,maxR,100)

# %% [markdown]
# ### read TC data

# %%
path='test/'

# %%
tc=pd.read_csv(path+'step2.txt',delimiter='\t')

# %%
tc
# Out:
#      time                    t      hurName   lat   lon  pcenter  penv  \
# 0     0.0  2010-10-29 06:00:00       INVEST   9.0 -53.7     1006  1009
# 1     6.0  2010-10-29 12:00:00       INVEST   9.8 -55.3     1003  1009
# 2    12.0  2010-10-29 18:00:00        TOMAS  10.8 -56.8      998  1009
# 3    18.0  2010-10-30 00:00:00        TOMAS  11.9 -57.8      999  1009
# 4    24.0  2010-10-30 06:00:00        TOMAS  12.7 -58.9      997  1009
# 5    30.0  2010-10-30 12:00:00        TOMAS  13.1 -60.1      993  1009
# 6    36.0  2010-10-30 18:00:00        TOMAS  13.3 -61.0      990  1009
# 7    42.0  2010-10-31 00:00:00        TOMAS  13.5 -61.7      982  1009
# 8    48.0  2010-10-31 06:00:00        TOMAS  13.8 -62.4      983  1009
# 9    54.0  2010-10-31 12:00:00        TOMAS  14.0 -63.3      988  1011
# 10   60.0  2010-10-31 18:00:00        TOMAS  14.2 -64.4      994  1010
# 11   66.0  2010-11-01 00:00:00        TOMAS  14.1 -65.8      997  1010
# 12   72.0  2010-11-01 06:00:00        TOMAS  13.9 -67.1     1003  1010
# 13   78.0  2010-11-01 12:00:00        TOMAS  13.6 -68.2     1005  1011
# 14   84.0  2010-11-01 18:00:00        TOMAS  13.5 -69.2     1005  1010
# 15   90.0  2010-11-02 00:00:00        TOMAS  13.5 -70.3     1005  1010
# 16   96.0  2010-11-02 06:00:00        TOMAS  13.5 -71.4     1003  1010
# 17  102.0  2010-11-02 12:00:00        TOMAS  13.5 -72.5     1004  1010
# 18  108.0  2010-11-02 18:00:00        TOMAS  13.6 -73.4     1006  1009
# 19  114.0  2010-11-03 00:00:00        TOMAS  13.8 -73.9     1006  1009
# 20  120.0  2010-11-03 06:00:00        TOMAS  14.0 -74.3     1006  1008
# 21  126.0  2010-11-03 12:00:00        TOMAS  14.3 -74.7     1006  1008
# 22  132.0  2010-11-03 18:00:00        TOMAS  14.7 -75.1     1004  1008
# 23  138.0  2010-11-04 00:00:00        TOMAS  15.1 -75.5     1003  1003
# 24  144.0  2010-11-04 06:00:00        TOMAS  15.5 -75.9      998  1007
# 25  150.0  2010-11-04 12:00:00        TOMAS  15.9 -76.2      996  1006
# 26  156.0  2010-11-04 18:00:00        TOMAS  16.4 -76.2      995  1006
# 27  162.0  2010-11-05 00:00:00        TOMAS  17.0 -75.7      989  1006
# 28  168.0  2010-11-05 06:00:00        TOMAS  17.7 -75.2      985  1006
# 29  174.0  2010-11-05 12:00:00        TOMAS  18.7 -74.7      987  1006
# 30  180.0  2010-11-05 18:00:00        TOMAS  19.7 -74.0      992  1006
# 31  186.0  2010-11-06 00:00:00        TOMAS  20.4 -73.1      995  1006
# 32  192.0  2010-11-06 06:00:00        TOMAS  21.4 -71.8      992  1006
# 33  198.0  2010-11-06 12:00:00        TOMAS  22.6 -70.9      990  1008
# 34  204.0  2010-11-06 18:00:00        TOMAS  23.8 -70.3      988  1009
# 35  210.0  2010-11-07 00:00:00        TOMAS  24.9 -69.8      987  1009
# 36  216.0  2010-11-07 06:00:00        TOMAS  25.4 -69.6      990  1009
# 37  222.0  2010-11-07 12:00:00        TOMAS  25.7 -69.5      992  1010
# 38  228.0  2010-11-07 18:00:00        TOMAS  26.0 -69.3      992  1008
# 39  240.0  2010-11-08 06:00:00        TOMAS  25.8 -67.5      992  1008
#
#         rmax       vmax      34ne    ...          w64nw      w50ne      w50se  \
# 0   222240.0  15.433333       0.0    ...       0.000000   0.000000   0.000000
# 1   166680.0  18.005556  138900.0    ...       0.000000   0.000000   0.000000
# 2    55560.0  23.150000  166680.0    ...       0.000000   0.000000   0.000000
# 3    55560.0  28.294444  166680.0    ...       0.000000  23.106896   0.000000
# 4    55560.0  30.866667  166680.0    ...       0.000000  23.344100   0.000000
# 5    37040.0  33.438889  222240.0    ...      30.031688  24.748161  25.130682
# 6    37040.0  41.155556  222240.0    ...      30.216264  24.889111  24.963993
# 7    37040.0  43.727778  222240.0    ...      30.399362  24.927226  24.798761
# 8    27780.0  43.727778  222240.0    ...      30.297483  25.333873  24.927432
# 9    27780.0  41.155556  222240.0    ...      30.017961  25.320538  25.224808
# 10   27780.0  33.438889  222240.0    ...       0.000000  24.885343  25.694846
# 11   55560.0  28.294444  277800.0    ...       0.000000  24.908241  26.038994
# 12   55560.0  23.150000  277800.0    ...       0.000000   0.000000   0.000000
# 13   55560.0  20.577778  222240.0    ...       0.000000   0.000000   0.000000
# 14   55560.0  20.577778  185200.0    ...       0.000000   0.000000   0.000000
# 15   55560.0  20.577778  185200.0    ...       0.000000   0.000000   0.000000
# 16   46300.0  23.150000  185200.0    ...       0.000000   0.000000   0.000000
# 17   46300.0  20.577778  185200.0    ...       0.000000   0.000000   0.000000
# 18   64820.0  18.005556  166680.0    ...       0.000000   0.000000   0.000000
# 19  111120.0  15.433333       0.0    ...       0.000000   0.000000   0.000000
# 20  111120.0  15.433333       0.0    ...       0.000000   0.000000   0.000000
# 21  138900.0  15.433333       0.0    ...       0.000000   0.000000   0.000000
# 22  138900.0  18.005556  111120.0    ...       0.000000   0.000000   0.000000
# 23  111120.0  20.577778  111120.0    ...       0.000000   0.000000   0.000000
# 24  111120.0  20.577778  138900.0    ...       0.000000   0.000000   0.000000
# 25  111120.0  23.150000  138900.0    ...       0.000000   0.000000   0.000000
# 26   74080.0  25.722222  185200.0    ...       0.000000  24.590603   0.000000
# 27   46300.0  30.866667  222240.0    ...       0.000000  24.735710   0.000000
# 28   46300.0  36.011111  222240.0    ...      33.126910  24.639962   0.000000
# 29   27780.0  38.583333  222240.0    ...      33.566656  25.183273  22.617946
# 30   37040.0  36.011111  185200.0    ...      33.644714  25.431094  22.628136
# 31   55560.0  30.866667  185200.0    ...       0.000000  25.626546  22.336534
# 32   37040.0  30.866667  185200.0    ...       0.000000  25.592693  22.078633
# 33   37040.0  30.866667  185200.0    ...       0.000000  25.478059  22.387261
# 34   37040.0  33.438889  185200.0    ...      33.367634  25.501064  22.717740
# 35   37040.0  36.011111  185200.0    ...      32.767567  25.657534  23.408630
# 36   37040.0  33.438889  185200.0    ...      32.083675  25.790321  24.133697
# 37   37040.0  30.866667  185200.0    ...       0.000000  24.964017  24.268058
# 38   37040.0  25.722222  185200.0    ...       0.000000   0.000000  25.580878
# 39   74080.0  25.722222  231500.0    ...       0.000000   0.000000  25.521330
#
#         w50sw      w50nw      w34ne      w34se      w34sw      w34nw  \
# 0    0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 1    0.000000   0.000000  17.394121   0.000000  18.059481  16.718113
# 2    0.000000   0.000000  18.074184  17.313465  18.366306  17.301589
# 3   25.859722   0.000000  18.316167  17.397022  18.525193  17.452947
# 4   25.728973   0.000000  18.496702  17.636008  18.632523  17.383112
# 5   25.443546  24.067929  19.599667  17.745589  18.645319  17.719449
# 6   25.297372  24.185329  19.678071  17.715329  18.630080  17.783646
# 7   25.291917  24.301841  19.727123  17.685447  18.658875  17.847466
# 8   25.512994  24.253146  19.783799  17.750702  18.727010  17.858079
# 9   25.584497  24.095087  19.813501  17.856080  18.784244  17.817282
# 10  25.512191  23.834531  19.847891  18.011960  18.834087  17.737395
# 11  25.594742  23.621115  20.812971  18.103497  18.801867  17.646507
# 12   0.000000   0.000000  20.778067  18.011076  18.730047  17.634630
# 13   0.000000   0.000000  19.759113  18.155385  18.026683  16.770374
# 14   0.000000   0.000000  19.077770  17.975981  18.053386  16.832031
# 15   0.000000   0.000000  19.065227   0.000000  17.775132  16.832064
# 16   0.000000   0.000000  19.065227   0.000000  17.744210  16.832064
# 17   0.000000   0.000000  19.071493   0.000000  17.709799  16.901810
# 18   0.000000   0.000000  18.787758   0.000000  17.578914   0.000000
# 19   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 20   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 21   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 22   0.000000   0.000000  17.899412   0.000000   0.000000  18.111761
# 23   0.000000   0.000000  17.947746   0.000000   0.000000  18.159972
# 24   0.000000   0.000000  18.580569   0.000000   0.000000  18.221249
# 25   0.000000   0.000000  18.666058   0.000000   0.000000  18.336435
# 26   0.000000  25.364791  19.705698   0.000000   0.000000  19.510294
# 27   0.000000  25.642265  20.557788   0.000000   0.000000  20.685705
# 28   0.000000  25.830457  20.683626  16.307850  17.499901  20.851881
# 29  25.183447  26.067173  20.884005  17.511327  18.202583  21.082086
# 30  25.001631  26.222075  20.326107  17.600342  18.180366  21.287300
# 31  24.840785  26.408090  20.484904  17.574264  18.147613  20.698453
# 32  25.073555  26.609532  20.624152  17.582617  18.328931  20.902475
# 33  25.460121  26.602513  20.767635  17.772961  18.598600  21.076086
# 34  25.640036  26.585281  20.945298  19.304223  19.751917  21.243355
# 35  25.602023  26.412720  21.142403  19.556017  19.868189  21.350423
# 36  25.492645  26.169100  21.248089  19.737979  19.894623  21.352524
# 37  25.439590  25.495108  21.308858  21.896364  21.952757  21.386631
# 38  25.609585   0.000000  21.450922  21.937124  21.942872  21.458845
# 39  25.434968   0.000000  22.608218  22.832495  24.529542  21.439422
#
#       vmax0vt
# 0    5.069814
# 1   18.059481
# 2   18.366306
# 3   25.859722
# 4   25.728973
# 5   30.031688
# 6   33.720308
# 7   36.492381
# 8   36.023263
# 9   32.757192
# 10  32.875995
# 11  26.038994
# 12  20.778067
# 13  19.759113
# 14  19.077770
# 15  19.065227
# 16  19.065227
# 17  19.071493
# 18  18.787758
# 19  11.721701
# 20  11.819292
# 21  11.507083
# 22  18.111761
# 23  18.159972
# 24  18.580569
# 25  18.862490
# 26  25.364791
# 27  25.642265
# 28  33.126910
# 29  33.566656
# 30  33.644714
# 31  26.408090
# 32  26.609532
# 33  26.602513
# 34  33.367634
# 35  32.767567
# 36  32.083675
# 37  26.701489
# 38  25.609585
# 39  25.521330
#
# [40 rows x 40 columns]

# %% [markdown]
# ### For one time ...

# %%
it=10

# %%
vmax=tc.loc[it].vmax

# %%
R=tc.ix[it,radcols].values

# %%
V=tc.ix[it,cols].values

# %%
vmax0vt = tc.vmax0vt.values[it]

# %%
time = tc.time.values[it]

# %%
sinfi = tc.sinfi.values[it]

# %%
lat=tc.lat.values[it]

# %%
w = R > 0.

# %%
R = R[w].astype(float)

# %%
V = V[w].astype(float)

# %%
R,V
# Out:
# (array([  27780.,   27780.,   92600.,   37040.,   74080.,   55560.,
#          222240.,   92600.,  166680.,  111120.]),
#  array([ 28.68809763,  32.87599512,  24.88534348,  25.69484591,
#          25.5121911 ,  23.83453082,  19.84789124,  18.01195988,
#          18.83408682,  17.73739542]))

# %% [markdown]
# ## Calculating using Monte Carlo

# %%
nb=10000  #size of random numbers used

# %%
npmin=2 # minimum number of velocities in order to...

npv=np.size(V)

# %%
if (npv>npmin):
     K=kmin+(kmax-kmin)*np.random.rand(nb)
elif(done):
     K = np.ones(nb)*ktot[t-1] # previous time step
else:
     K = np.ones(nb)*kmin

# %%
#  DP
DP=dpmin*(dpmax/dpmin)**np.random.rand(nb)

#  Rmax
rvmaxmin_=np.min([rvmaxmin,np.min(R)*0.5])  # update the minimum  value for Rmax with the R.min/2 from input
RMAX=rvmaxmin_*(np.min(R)*0.99/rvmaxmin_)**np.random.rand(nb) # range  min(10000,Rmin/2)<Rmax<.99*Rmin (scaled)

# %%
#--------------------------------------------------
# calculate vmax1 = v max0k -vt - Coriolis effect (function of RMAX)
#--------------------------------------------------
deltalatvmax=RMAX/deg2m*sinfi  # for each Rmax we compute the lat deviation for the velocity
latvmax=lat+deltalatvmax

fvmax=2*omega*np.abs(np.sin(np.radians(latvmax))) # Coriolis coef f

fvmax2=RMAX*fvmax/2
vmax1=((vmax0vt+fvmax2)**2-fvmax2**2)**0.5
mask=vmax1<np.max(V)
np.copyto(vmax1,np.max(V),where=mask)

#----------------------------------
# use the random values of vmax,dp above we compute b (from Holland 2010 - eqs (7))
#----------------------------------

B=(rhoa*np.exp(1)/DP)*vmax1**2


m=(B >= bmin) & ( B <= bmax) & (lat*latvmax > 0)  # mask B that fits all 3 criteria
nb1 = np.sum(m) #number of 'True' values

#  mask arrays accordingly
K=K[m]
DP=DP[m]
RMAX=RMAX[m]
B = B[m]

nval = np.size(V)  # number of V > 0
Vcalc = []
RMS = np.zeros(nb1)

#try:
#        r
#except NameError:
#        pass
#else:
#        r=None

# check values for all V
for i in range(nval):
      try:
        r = R[i]
        ratio=(r-RMAX)/(maxR-RMAX)
        X=0.5 + np.min([np.max(ratio,0),1])*K   #compute x using random k  & Rmax
        Vcalc=np.append(Vcalc,((B/rhoa) * DP* (RMAX/r)**B * np.exp(-(RMAX/r)**B))**X)  # compute & store V
      except: print 'sys.exit()'

for i in range (nb1):
      try:
        RMS[i]=np.sqrt(np.average((Vcalc[i::nb1]-V)**2))  # compute deviation from estimated and given values
      except : print 'sys.exit()'

value=nb1
totvalue=nb

# -------------------------------------------------------------------------
# select final velocities
# -------------------------------------------------------------------------
m=RMS == np.min(RMS)  #find minimum RMS

# select the minimizing quantities
rmse=RMS[m][0]
dpMC=DP[m][0]
bMC=B[m][0]
rmaxMC=RMAX[m][0]
kMC=K[m][0]

vmax1MC = np.sqrt(bMC*dpMC/(rhoa*np.exp(1)))  # compute estimated vmax


# print on screen
var=[rmse,dpMC,bMC,rmaxMC,kMC ,np.max(V),vmax1MC]
varn=['rmse','dp','b','rmax','k','np.max(V)','vmax1']

mcdic={el:val for (el,val) in zip(varn,var)}

# %%
mcdic
# Out:
# {'b': 1.0600373304787125,
#  'dp': 3227.1887378675733,
#  'k': 0.24575807816385373,
#  'np.max(V)': 32.875995116399999,
#  'rmax': 11515.616920958495,
#  'rmse': 2.383978589588108,
#  'vmax1': 33.080845530492326}

# %% [markdown]
# ## Calculating using Scipy

# %%
idx4 = [3, 0, 1, 2] # change the order of the variables to match the arguments in hvel()

# %%
idx3 = [0, 1, 2] # change the order of the variables to match the arguments in hvel()

# %%
#
try:
    dp_=tc.loc[it].dp
except:
    pass

# %%
# p[0] = B
# p[1] = Rmax
# p[2] = k
# p[3] = dp

def slsqp(R,V,vmax,**kwargs):

    if 'dp' in kwargs.keys():
        dp_=kwargs['dp']
        def func(p,x):
                 return (p[0]/rhoa*(p[1]/x)**p[0]*dp_*np.exp(-(p[1]/x)**p[0]))**(0.5+(x-p[1])/(maxR-p[1])*p[2]) # given dp
        def cf(p,x,y):
                 return p[0]-vmax**2*rhoa*np.exp(1.)/dp_ # given dp
        
        p0=[b0,rmax0,k0] # initial values

        bp=[(bmin,bmax),(rmaxmin,R.min()*.99),(kmin,kmax)]


    else:
        def func(p,x):
                 return (p[0]/rhoa*(p[1]/x)**p[0]*p[3]*np.exp(-(p[1]/x)**p[0]))**(0.5+(x-p[1])/(maxR-p[1])*p[2]) # complete
        def cf(p,x,y):
                 return p[0]-vmax**2*rhoa*np.exp(1.)/p[3] # complete
        
        p0=[b0,rmax0,k0,dp0] # initial values
        bp=[(bmin,bmax),(rmaxmin,R.min()*.99),(kmin,kmax),(dpmin,dpmax)]



    def errf(p,x,y):
            return np.sum((func(p,x)-y)**2)

    def fun(p,x,y):
        return func(p,x)-y

    cons = ({'type': 'ineq',
             'fun' : lambda p: np.array([p[0]-vmax**2*rhoa*np.exp(1.)/p[3]]),
             'jac' : lambda p: np.array([1.0, 0.0, 0.0, vmax**2*rhoa*np.exp(1.)/(p[3]**2)])},
           {'type': 'ineq',
             'fun' : lambda p: np.array([-p[0]+vmax**2*rhoa*np.exp(1.)/p[3]]),
             'jac' : lambda p: np.array([-1.0, 0.0, 0.0, -vmax**2*rhoa*np.exp(1.)/(p[3]**2)])})
           
            
    res1 = minimize(errf, p0, args=(R, V), method='L-BFGS-B', bounds=bp, \
                        options={'disp': True, 'maxls': 20, 'iprint': -1, 'gtol': 1e-05, 'eps': 1e-08, 'maxiter': 15000, 'ftol': 2.220446049250313e-09, 'maxcor': 10, 'maxfun': 15000})
    print ('L-BFGS-B', res1.x)
    res2 = minimize(errf, p0, args=(R, V),  bounds=bp, method='SLSQP', tol=1e-3, options={'disp': True, 'iprint': 1, 'eps': 1.4901161193847656e-08, 'maxiter': 100, 'ftol': 1e-06})
    print ('SLSQP', res2.x, res2.fun, res2.message)
    res = fmin_slsqp(errf, p0, bounds=bp, args=(R, V),f_ieqcons=cf,acc=1e-5)

    res0 = least_squares(fun, p0, args=(R, V), verbose=1)



    print (res)

    print ('Rmax= ', res1.x[1],res2.x[1])
    print ('F(Rmax)= ', cf(res1.x,0.,0.), cf(res2.x,0.,0.))
    return func,res1.x,res2.x, res, res0

# %%
fitf2,p2,p3,p4,p5=slsqp(R,V,vmax0vt)
# Out:
# ('L-BFGS-B', array([  1.23517340e+00,   2.00437043e+04,   2.50000000e-01,
#          2.21337915e+03]))
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 54.8357016019
#             Iterations: 53
#             Function evaluations: 329
#             Gradient evaluations: 53
# ('SLSQP', array([  9.69121054e-01,   5.00000000e+03,   2.50000000e-01,
#          5.89796026e+03]), 54.8357016018929, 'Optimization terminated successfully.')
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 54.8357015562
#             Iterations: 54
#             Function evaluations: 336
#             Gradient evaluations: 54
# The maximum number of function evaluations is exceeded.
# Function evaluations 400, initial cost 1.1276e+03, final cost 2.7138e+01, first-order optimality 5.29e-01.
# [  9.69115104e-01   5.00000000e+03   2.50000000e-01   5.89784724e+03]
# ('Rmax= ', 20043.704310596931, 5000.0)
# ('F(Rmax)= ', -0.29131786050387665, 0.39626132347281173)

# %%
p3,p4,p5.x
# Out:
# (array([  9.69121054e-01,   5.00000000e+03,   2.50000000e-01,
#           5.89796026e+03]),
#  array([  9.69115104e-01,   5.00000000e+03,   2.50000000e-01,
#           5.89784724e+03]),
#  array([  9.10472967e-01,   2.21381476e+02,   2.75991344e-01,
#           7.85899609e+04]))

# %% [markdown]
# ## plot and compare

# %%
plt.figure()
if p4.size < 4:
    plt.plot(rh, hvel(rh, dp_, *p2[idx3]), 'b-', label='L-BFGS-B')
    plt.plot(rh, hvel(rh, dp_,  *p3[idx3]), 'cx-', label='SLSQP')
    plt.plot(rh, hvel(rh, dp_, *p4[idx3]), 'g-', label='fmin_slsqp')
    plt.plot(rh, hvel(rh, dp_, *p5.x[idx3]), 'k-', label='least_squares')




else:
    plt.plot(rh, hvel(rh, *p2[idx4]), 'b-', label='L-BFGS-B')
    plt.plot(rh, hvel(rh, *p3[idx4]), 'cx-', label='SLSQP')
    plt.plot(rh, hvel(rh, *p4[idx4]), 'g-',  label='fmin_slsqp')
    plt.plot(rh, hvel(rh, *p5.x[idx4]), 'k-', label='least_squares')




try:
    plt.plot(rh, hvel(rh, dpMC, bMC, rmaxMC, kMC), 'r-', label='Monte Carlo')
except:pass



plt.scatter(R,V,color='k',marker='x',s=20)
plt.plot(rh,np.ones(rh.size)*vmax0vt,'k--', label='Vmax-Vt-Vcor')

plt.legend(loc=0)
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print jj
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a5ffc3e77204> in <module>()
# ----> 1 print jj
#
# NameError: name 'jj' is not defined

# %%
# select solution
bh, rmaxh, kh, dph = p4

# %% [markdown]
# ## Plot profile

# %%
xl=np.linspace(-maxR, maxR,1000)
yl=np.linspace(-maxR, maxR,1000)
q1,q2=np.meshgrid(xl,yl)
vtx=outData.vtrx
vty=outData.vtry

# %%
def pres(r):
    return pn+dph*np.exp(-(rmaxh/r)**bh)

# %%
def hvel2d(l1,l2):
    r=np.sqrt(l1**2+l2**2)
    xh=0.5+(r-rmaxh)/(maxR-rmaxh)*kh
    ur=(bh/rhoa*(rmaxh/r)**bh*dph*np.exp(-(rmaxh/r)**bh))**xh
    theta=np.arctan2(l2,l1)
    ux=-ur*np.sin(theta)
    uy=ur*np.cos(theta)
    return ux+vtx,uy+vty, pres(r)

# %%
zx,zy, pr=hvel2d(q1,q2)
vel=np.sqrt(zx**2+zy**2)

# %%
plt.figure(figsize=(10,8))
plt.contourf(q1,q2,vel,20)
plt.streamplot(q1,q2,zx,zy, color=vel, linewidth=0.1*vel)
plt.colorbar()
plt.show()

# %% [markdown]
# # Test the scripts

# %% [markdown]
# For all times using external scripts

# %%
from mc import mc
from slsqp import slsqp

# %%
varn=['rmse','dph','b','rmaxh','k','np.max(V)','vmax1']
mcdic={el:[] for el in varn}

# %%
hpar= pd.DataFrame(mcdic)

# %%
for it in range(tc.shape[0]):
   
    vmax=tc.loc[it].vmax

#
#try:
#    dp=tc.loc[it].dp
#except:
#    pass

    R=tc.ix[it,radcols].values

    V=tc.ix[it,cols].values

    vmax0vt = tc.vmax0vt.values[it]

    time = tc.time.values[it]

    sinfi = tc.sinfi.values[it]

    lat=tc.lat.values[it]

    w = R > 0.

    R = R[w].astype(float)

    V = V[w].astype(float)

    if R.size > 0 : 
        rmc = mc(R,V,sinfi,lat,vmax0vt)
        rmc_ = slsqp(R,V,vmax0vt)
    else:
        rmc = {el:'' for el in varn}
        rmc_ = {el:'' for el in varn}


    print rmc_
    df1 = pd.DataFrame(rmc,index=[it])
    df2 = pd.DataFrame(rmc_,index=[it])


    
    hpar = hpar.append([df1,df2])
# Out:
# {'vmax1': '', 'b': '', 'rmse': '', 'k': '', 'rmaxh': '', 'np.max(V)': '', 'dph': ''}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4886514984
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.48867471225
#             Iterations: 11
#             Function evaluations: 68
#             Gradient evaluations: 11
# {'vmax1': 18.481324001210311, 'b': 0.80000000000001259, 'rmse': 0.70443232753966245, 'k': 0.25, 'rmaxh': 20001.611825499072, 'np.max(V)': 18.059480947600001, 'dph': 1334.653399333037}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.911711665741
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.91175347682
#             Iterations: 10
#             Function evaluations: 62
#             Gradient evaluations: 10
# {'vmax1': 18.838550210761415, 'b': 0.80000000000002935, 'rmse': 0.47742891534225401, 'k': 0.25, 'rmaxh': 20001.766036044115, 'np.max(V)': 18.3663061572, 'dph': 1386.7471733751802}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 23.738530102
#             Iterations: 19
#             Function evaluations: 118
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 23.7386263773
#             Iterations: 15
#             Function evaluations: 91
#             Gradient evaluations: 15
# {'vmax1': 27.213402880863576, 'b': 1.2293558295413094, 'rmse': 1.9890796187061943, 'k': 0.2499999999997824, 'rmaxh': 20005.327048310515, 'np.max(V)': 25.859721655100003, 'dph': 1883.1305099138619}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 22.9498746634
#             Iterations: 19
#             Function evaluations: 118
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 22.9499701156
#             Iterations: 15
#             Function evaluations: 91
#             Gradient evaluations: 15
# {'vmax1': 27.175445453391664, 'b': 1.2204816785138237, 'rmse': 1.9557594482117469, 'k': 0.24999999999976277, 'rmaxh': 20005.35185007954, 'np.max(V)': 25.728973410799998, 'dph': 1891.5350854323606}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 57.9295010665
#             Iterations: 18
#             Function evaluations: 112
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 58.7200260127
#             Iterations: 9
#             Function evaluations: 57
#             Gradient evaluations: 9
# {'vmax1': 30.031687771781762, 'b': 1.259272441215922, 'rmse': 2.4232215336756302, 'k': 0.2499999999934456, 'rmaxh': 20000.737095995544, 'np.max(V)': 30.0316877719, 'dph': 2238.8866327617002}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 61.2146313958
#             Iterations: 18
#             Function evaluations: 112
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 58.552167615
#             Iterations: 60
#             Function evaluations: 378
#             Gradient evaluations: 60
# {'vmax1': 45.283695345050312, 'b': 1.0078778194338138, 'rmse': 2.4197555168858309, 'k': 0.24999999999999886, 'rmaxh': 5000.0, 'np.max(V)': 30.216264399499998, 'dph': 6360.1616586391028}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 96.2208021439
#             Iterations: 37
#             Function evaluations: 228
#             Gradient evaluations: 37
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 103.997388373
#             Iterations: 34
#             Function evaluations: 216
#             Gradient evaluations: 34
# {'vmax1': 36.492345431228031, 'b': 0.80897430730551967, 'rmse': 2.9438833249770573, 'k': 0.071611749631017976, 'rmaxh': 7928.7292098486541, 'np.max(V)': 32.008721117199997, 'dph': 5145.8976949876933}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 112.65979624
#             Iterations: 21
#             Function evaluations: 131
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 117.21974977
#             Iterations: 35
#             Function evaluations: 217
#             Gradient evaluations: 35
# {'vmax1': 36.023263491529427, 'b': 0.80000000000000004, 'rmse': 3.1254299673583672, 'k': 0.081403966020693538, 'rmaxh': 8170.6019887287948, 'np.max(V)': 32.1363804362, 'dph': 5070.7061623066929}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 110.168508191
#             Iterations: 21
#             Function evaluations: 131
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 110.490274927
#             Iterations: 14
#             Function evaluations: 87
#             Gradient evaluations: 14
# {'vmax1': 32.757192297911985, 'b': 1.2095114640001705, 'rmse': 3.03439003930291, 'k': 0.24999999999999994, 'rmaxh': 16808.547093502053, 'np.max(V)': 32.522232511399999, 'dph': 2773.292477298296}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 54.8357016019
#             Iterations: 53
#             Function evaluations: 329
#             Gradient evaluations: 53
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 54.8357015562
#             Iterations: 54
#             Function evaluations: 336
#             Gradient evaluations: 54
# {'vmax1': 42.760057437046832, 'b': 0.96911510372420029, 'rmse': 2.3417024054349103, 'k': 0.25, 'rmaxh': 5000.0000000000155, 'np.max(V)': 32.875995116399999, 'dph': 5897.8472428905789}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 52.7256544587
#             Iterations: 16
#             Function evaluations: 100
#             Gradient evaluations: 16
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 52.72571053
#             Iterations: 13
#             Function evaluations: 80
#             Gradient evaluations: 13
# {'vmax1': 26.508381961860064, 'b': 1.0646497007924351, 'rmse': 2.5672385584994482, 'k': 0.25, 'rmaxh': 20005.703673936423, 'np.max(V)': 26.038993917500001, 'dph': 2063.2508152833602}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.3902782172
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 6.40447425272
#             Iterations: 11
#             Function evaluations: 69
#             Gradient evaluations: 11
# {'vmax1': 20.778066424956286, 'b': 0.85819315946866115, 'rmse': 1.2653531377368787, 'k': 0.25, 'rmaxh': 20002.185946409314, 'np.max(V)': 20.778066566500001, 'dph': 1572.5973315007504}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.30891323709
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 7.2836971022
#             Iterations: 12
#             Function evaluations: 75
#             Gradient evaluations: 12
# {'vmax1': 19.759112978077432, 'b': 0.82575360423083877, 'rmse': 1.3494162721520946, 'k': 0.25, 'rmaxh': 20002.136925021558, 'np.max(V)': 19.759113016899999, 'dph': 1478.0078243584892}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.6044249939
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.05249930245
#             Iterations: 11
#             Function evaluations: 69
#             Gradient evaluations: 11
# {'vmax1': 19.077769733077535, 'b': 0.80000000000000004, 'rmse': 1.0065410203329199, 'k': 0.24999999999965622, 'rmaxh': 20002.046921915953, 'np.max(V)': 19.077770210899999, 'dph': 1422.1897374645619}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.78927276705
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.02274594681
#             Iterations: 11
#             Function evaluations: 70
#             Gradient evaluations: 11
# {'vmax1': 19.065226951583089, 'b': 0.80000000000005922, 'rmse': 1.0037838324405226, 'k': 0.25, 'rmaxh': 20002.008449719167, 'np.max(V)': 19.0652269516, 'dph': 1420.3202997413573}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.04058915928
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.52832295324
#             Iterations: 12
#             Function evaluations: 75
#             Gradient evaluations: 12
# {'vmax1': 19.065226951531802, 'b': 0.80000000000000004, 'rmse': 1.0844849704262116, 'k': 0.24999999999993569, 'rmaxh': 20002.007305750612, 'np.max(V)': 19.0652269516, 'dph': 1420.3202997338203}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 2.95260179973
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.4234277128
#             Iterations: 12
#             Function evaluations: 75
#             Gradient evaluations: 12
# {'vmax1': 19.071493233796875, 'b': 0.80000000000000004, 'rmse': 1.0682427490665398, 'k': 0.24999999999993622, 'rmaxh': 20002.012498905355, 'np.max(V)': 19.071493233800002, 'dph': 1421.2541035177178}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.6079555862
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.60799751894
#             Iterations: 11
#             Function evaluations: 69
#             Gradient evaluations: 11
# {'vmax1': 18.981007335293526, 'b': 0.80000000000001315, 'rmse': 0.89665977910683492, 'k': 0.25, 'rmaxh': 20001.921935640537, 'np.max(V)': 18.7877583826, 'dph': 1407.7996383220852}
# {'vmax1': '', 'b': '', 'rmse': '', 'k': '', 'rmaxh': '', 'np.max(V)': '', 'dph': ''}
# {'vmax1': '', 'b': '', 'rmse': '', 'k': '', 'rmaxh': '', 'np.max(V)': '', 'dph': ''}
# {'vmax1': '', 'b': '', 'rmse': '', 'k': '', 'rmaxh': '', 'np.max(V)': '', 'dph': ''}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0225459577101
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0225459529485
#             Iterations: 11
#             Function evaluations: 69
#             Gradient evaluations: 11
# {'vmax1': 19.160041222888118, 'b': 0.80000000000000004, 'rmse': 0.10617427406978665, 'k': 0.25, 'rmaxh': 20002.266389512446, 'np.max(V)': 18.111760910799998, 'dph': 1434.4823648878594}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0225199447033
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0225199391057
#             Iterations: 11
#             Function evaluations: 69
#             Gradient evaluations: 11
# {'vmax1': 19.206940377618373, 'b': 0.80000000000000004, 'rmse': 0.10611300369339788, 'k': 0.25, 'rmaxh': 20002.301775580105, 'np.max(V)': 18.159972233000001, 'dph': 1441.5134925686357}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0647885718338
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.064790982545
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 19.546429041722007, 'b': 0.80000000000000004, 'rmse': 0.17998747532114404, 'k': 0.25, 'rmaxh': 20002.388286079517, 'np.max(V)': 18.580569313599998, 'dph': 1492.9222469134068}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0536774892617
#             Iterations: 10
#             Function evaluations: 60
#             Gradient evaluations: 10
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.0536796952686
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 19.642237802298567, 'b': 0.80000000000000082, 'rmse': 0.1638287143156556, 'k': 0.25, 'rmaxh': 20002.467650372499, 'np.max(V)': 18.6660584075, 'dph': 1507.5935283020513}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.415271682704
#             Iterations: 21
#             Function evaluations: 132
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.415277305404
#             Iterations: 19
#             Function evaluations: 118
#             Gradient evaluations: 19
# {'vmax1': 28.240552264001867, 'b': 1.1394164255544665, 'rmse': 0.32221006556444187, 'k': 0.25, 'rmaxh': 20007.113769321844, 'np.max(V)': 25.364791185799998, 'dph': 2188.0448368539974}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.419102681958
#             Iterations: 15
#             Function evaluations: 95
#             Gradient evaluations: 15
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.419102714484
#             Iterations: 14
#             Function evaluations: 88
#             Gradient evaluations: 14
# {'vmax1': 27.76466476456239, 'b': 1.0532250534795018, 'rmse': 0.3236907144498834, 'k': 0.24056410960443639, 'rmaxh': 20007.449576411189, 'np.max(V)': 25.642265287199997, 'dph': 2287.9999422053397}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 127.034087162
#             Iterations: 47
#             Function evaluations: 290
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 127.034086408
#             Iterations: 35
#             Function evaluations: 214
#             Gradient evaluations: 35
# {'vmax1': 39.702184881120857, 'b': 0.9271455217620348, 'rmse': 3.9848790196193864, 'k': 0.25, 'rmaxh': 5000.0000011756265, 'np.max(V)': 33.126910446399997, 'dph': 5314.6324159723872}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 85.2319401123
#             Iterations: 46
#             Function evaluations: 280
#             Gradient evaluations: 46
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 85.2319402618
#             Iterations: 39
#             Function evaluations: 243
#             Gradient evaluations: 39
# {'vmax1': 41.575835284046512, 'b': 0.93970245573123745, 'rmse': 2.6650819290382581, 'k': 0.25, 'rmaxh': 5000.0000002653278, 'np.max(V)': 33.566656494100002, 'dph': 5750.2129302102312}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 89.8087919307
#             Iterations: 47
#             Function evaluations: 286
#             Gradient evaluations: 47
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 89.8087956302
#             Iterations: 39
#             Function evaluations: 241
#             Gradient evaluations: 39
# {'vmax1': 42.250059893626563, 'b': 0.94667163372035124, 'rmse': 2.9968115661516066, 'k': 0.25, 'rmaxh': 5000.0000000005202, 'np.max(V)': 33.644714325199999, 'dph': 5894.5087419605625}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 63.3983217926
#             Iterations: 22
#             Function evaluations: 143
#             Gradient evaluations: 22
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 65.8580863421
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 26.408090082605, 'b': 1.060630374457455, 'rmse': 2.8691916619085109, 'k': 0.24999999999999425, 'rmaxh': 20005.748590542371, 'np.max(V)': 26.408090105100001, 'dph': 2055.4279010072069}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 65.7104057511
#             Iterations: 23
#             Function evaluations: 144
#             Gradient evaluations: 23
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 69.4548333189
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 26.609532147147672, 'b': 1.0640476203556599, 'rmse': 2.9464986280086078, 'k': 0.24999999999999836, 'rmaxh': 20005.882968300921, 'np.max(V)': 26.609532173400002, 'dph': 2080.2030798385185}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 61.855088302
#             Iterations: 21
#             Function evaluations: 136
#             Gradient evaluations: 21
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 64.4715781785
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 26.602513166909922, 'b': 1.0545547730506153, 'rmse': 2.8388285035048137, 'k': 0.24999999999999986, 'rmaxh': 20005.961572116448, 'np.max(V)': 26.6025131932, 'dph': 2097.8214136685392}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 74.1403472941
#             Iterations: 20
#             Function evaluations: 124
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 74.6742104426
#             Iterations: 43
#             Function evaluations: 264
#             Gradient evaluations: 43
# {'vmax1': 33.367626871233448, 'b': 0.91741839869049469, 'rmse': 2.7326582377348219, 'k': 0.14554697516288098, 'rmaxh': 12346.778694410395, 'np.max(V)': 33.367634376700003, 'dph': 3793.8094808906076}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 60.7883210262
#             Iterations: 20
#             Function evaluations: 124
#             Gradient evaluations: 20
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 73.0881072841
#             Iterations: 9
#             Function evaluations: 56
#             Gradient evaluations: 9
# {'vmax1': 32.76755562780621, 'b': 1.2795045075317057, 'rmse': 2.7034812239800261, 'k': 0.25, 'rmaxh': 20002.774756915347, 'np.max(V)': 32.7675673034, 'dph': 2623.2434239513927}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 48.7210414535
#             Iterations: 18
#             Function evaluations: 112
#             Gradient evaluations: 18
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 48.8519823967
#             Iterations: 38
#             Function evaluations: 235
#             Gradient evaluations: 38
# {'vmax1': 32.083669017538874, 'b': 1.1107301642873808, 'rmse': 2.2102484565471952, 'k': 0.24868606703517385, 'rmaxh': 15890.322242910275, 'np.max(V)': 32.0836751561, 'dph': 2897.0221173332652}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 3.12315689359
#             Iterations: 25
#             Function evaluations: 156
#             Gradient evaluations: 25
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 4.48024362371
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12
# {'vmax1': 26.70148932122234, 'b': 0.99727296020798584, 'rmse': 0.748351824320731, 'k': 0.24999999999841754, 'rmaxh': 20006.282142829157, 'np.max(V)': 25.4951083192, 'dph': 2234.8544785454278}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.605383133791
#             Iterations: 19
#             Function evaluations: 121
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.605343283325
#             Iterations: 18
#             Function evaluations: 115
#             Gradient evaluations: 18
# {'vmax1': 30.265769660634589, 'b': 1.1099542599732961, 'rmse': 0.31763272378781904, 'k': 0.25, 'rmaxh': 20006.202498768627, 'np.max(V)': 25.609584567700001, 'dph': 2579.8276016181362}
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.81365420922
#             Iterations: 19
#             Function evaluations: 122
#             Gradient evaluations: 19
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.81342308386
#             Iterations: 13
#             Function evaluations: 81
#             Gradient evaluations: 13
# {'vmax1': 28.860720207198302, 'b': 1.0354863119005717, 'rmse': 0.54976102139308924, 'k': 0.24999999999980116, 'rmaxh': 20004.71619401301, 'np.max(V)': 25.521329934499999, 'dph': 2514.561657063819}

# %%
comp = pd.concat([hpar.iloc[::2,:], hpar.iloc[1::2,:]], axis=1)

# %%
comp['dph'].apply(pd.to_numeric).plot()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## Write outData file

# %%
outData = pd.concat([tc,hpar.iloc[::2,:]],axis=1) # append to tc Dataset Monte Carlo solution

# %%
outData.head()
# Out:
#    time                    t      hurName   lat   lon  pcenter  penv  \
# 0   0.0  2010-10-29 06:00:00       INVEST   9.0 -53.7     1006  1009
# 1   6.0  2010-10-29 12:00:00       INVEST   9.8 -55.3     1003  1009
# 2  12.0  2010-10-29 18:00:00        TOMAS  10.8 -56.8      998  1009
# 3  18.0  2010-10-30 00:00:00        TOMAS  11.9 -57.8      999  1009
# 4  24.0  2010-10-30 06:00:00        TOMAS  12.7 -58.9      997  1009
#
#        rmax       vmax      34ne   ...         w34sw      w34nw    vmax0vt  \
# 0  222240.0  15.433333       0.0   ...      0.000000   0.000000   5.069814
# 1  166680.0  18.005556  138900.0   ...     18.059481  16.718113  18.059481
# 2   55560.0  23.150000  166680.0   ...     18.366306  17.301589  18.366306
# 3   55560.0  28.294444  166680.0   ...     18.525193  17.452947  25.859722
# 4   55560.0  30.866667  166680.0   ...     18.632523  17.383112  25.728973
#
#           b      dph         k  np.max(V)    rmaxh      rmse    vmax1
# 0
# 1  0.814397  1288.69  0.235803    18.0595  21236.8  0.832487   18.323
# 2  0.844967  1291.04   0.23835    18.3663    22990  0.705101  18.6807
# 3   1.07689  1981.09  0.234723    25.8597  17570.5   2.03782  26.1242
# 4   1.15893  1829.74  0.223864     25.729  19772.1   1.98471  26.0452
#
# [5 rows x 47 columns]

# %%
header=['time','xhc','yhc','b','k','rmax','deltap','vmax','vmax0','vtr','vtrx','vtry','bias','rmse']

# %%
outData.columns.values
# Out:
# array(['time', 't', 'hurName', 'lat', 'lon', 'pcenter', 'penv', 'rmax',
#        'vmax', '34ne', '34se', '34sw', '34nw', '50ne', '50se', '50sw',
#        '50nw', '64ne', '64se', '64sw', '64nw', 'dp', 'vtrx', 'vtry', 'vtr',
#        'cosfi', 'sinfi', 'w64ne', 'w64se', 'w64sw', 'w64nw', 'w50ne',
#        'w50se', 'w50sw', 'w50nw', 'w34ne', 'w34se', 'w34sw', 'w34nw',
#        'vmax0vt', 'b', 'dph', 'k', 'np.max(V)', 'rmaxh', 'rmse', 'vmax1'], dtype=object)

# %%
column_order=['time','lat','lon','b','k','rmaxh','dph','vmax','vmax0','vtr','vtrx','vtrxy','bias','rmse']

# %%
outData.to_csv(path+'outData.txt',index=False, columns=column_order, sep='\t',header=header)

# %%
outData.to_csv(path+'step3.txt',index=False, sep='\t')

# %%
outData.iloc[10]
# Out:
# time                          60
# t            2010-10-31 18:00:00
# hurName                    TOMAS
# lat                         14.2
# lon                        -64.4
# pcenter                      994
# penv                        1010
# rmax                       27780
# vmax                     33.4389
# 34ne                      222240
# 34se                       92600
# 34sw                      166680
# 34nw                      111120
# 50ne                       92600
# 50se                       37040
# 50sw                       74080
# 50nw                       55560
# 64ne                       27780
# 64se                           0
# 64sw                       27780
# 64nw                           0
# dp                          1600
# vtrx                    -6.24551
# vtry                    0.257694
# vtr                      6.25082
# cosfi                  -0.999201
# sinfi                   0.039968
# w64ne                    28.6881
# w64se                          0
# w64sw                     32.876
# w64nw                          0
# w50ne                    24.8853
# w50se                    25.6948
# w50sw                    25.5122
# w50nw                    23.8345
# w34ne                    19.8479
# w34se                     18.012
# w34sw                    18.8341
# w34nw                    17.7374
# vmax0vt                   32.876
# b                        1.03985
# dph                      3288.18
# k                        0.24238
# np.max(V)                 32.876
# rmaxh                    11044.3
# rmse                     2.38628
# vmax1                    33.0725
# Name: 10, dtype: object
