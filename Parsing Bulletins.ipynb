# %%
import feedparser

# %%
from readxml import readxml

# %%
url='http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml'

jmafeed=feedparser.parse(url)


data=jmafeed['entries']
data[0]['summary']
# Out:
# u'<pre>TD expected upgrading\nANALYSIS (0312UTC):\nPressure 1004 hPa\nat 7.6 degree north 131.6 degree east\nposition POOR (radius more than 110 km).\nMoving west-north-west 9 knots.\nMax winds 30 knots.\nGust 45 knots.\n</pre>'

# %%
print readxml(url,'lxml')
# Out:
# 2017-02-03T13:35:03Z
# Typhoon Advisories from RSMC Tokyo
# https://ds.data.jma.go.jp/fcd/yoho/cap-rsmctk/
# RSMC Tokyo - Typhoon Centre
# 2017-02-03T13:05:42.001Z
# TD expected upgrading ANALYSIS (0312UTC): 7.6°N 131.6°E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt
# TD expected upgrading
# ANALYSIS (0312UTC):
# Pressure 1004 hPa
# at 7.6 degree north 131.6 degree east
# position POOR (radius more than 110 km).
# Moving west-north-west 9 knots.
# Max winds 30 knots.
# Gust 45 knots.
# urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941
# urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941
# rsmc-tokyo@met.kishou.go.jp
# 2017-02-03T13:05:42+00:00
# Actual
# Alert
# Public
# CAP-RSMCTK
# en-US
# Met
# TROPICAL CYCLONE ADVISORY/ANALYSIS
# Unknown
# Unknown
# Observed
# EventType
# TC_Analysis
# 2017-02-03T13:10:00+00:00
# 2017-02-03T12:00:00+00:00
# 2017-02-03T19:30:00+00:00
# RSMC Tokyo - Typhoon Center
# TD expected upgrading ANALYSIS (0312UTC): 7.6°N 131.6°E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt
# TD expected upgrading
# ANALYSIS (0312UTC):
# Pressure 1004 hPa
# at 7.6 degree north 131.6 degree east
# position POOR (radius more than 110 km).
# Moving west-north-west 9 knots.
# Max winds 30 knots.
# Gust 45 knots.
# http://www.jma.go.jp/en/typh/index.html
# TC_Number
# 1702
# TC_Remark
# Upgrading
# TC_Classification
# TD
# TC_MovingDirection
# WNW
# TC_MovingSpeed
# 9 kt
# TC_PositionConfidence
# POOR
# TC_CenterPressure
# 1004 hPa
# TC_Location
# ミンダナオ島の東
# TC_MaxSustainedWind
# 30 kt
# TC_PeakGust
# 45 kt
# EventEndTime
# 2017-02-03T12:00:00+00:00
# TC_AnalysisTime
# 2017-02-03T12:00:00+00:00
# UUID
# eb13a68c-97b3-3ba7-a967-9b4e93337941
# Sea East of Mindanao
# 7.6,131.6 0
# 2017-02-03T13:05:42.002Z
# TD expected upgrading FCST 24h (0412UTC): 9.6°N 130.0°E ±200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt
# TD expected upgrading
# Forecast 24 hr (0412UTC):
# Pressure 1000 hPa
# at 9.6 degree north 130.0 degree east
# with 200 km of 70 percent probability circle.
# Moving north-west 6 knots.
# Max winds 35 knots.
# Gust 50 knots.
# Expected to be TROPICAL STORM.
# urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb
# urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb
# rsmc-tokyo@met.kishou.go.jp
# 2017-02-03T13:05:42+00:00
# Actual
# Alert
# Public
# CAP-RSMCTK
# en-US
# Met
# TROPICAL CYCLONE ADVISORY/FORECAST
# Unknown
# Unknown
# Observed
# EventType
# TC_Forecast24
# 2017-02-03T13:10:00+00:00
# 2017-02-04T12:00:00+00:00
# 2017-02-03T19:30:00+00:00
# RSMC Tokyo - Typhoon Center
# TD expected upgrading FCST 24h (0412UTC): 9.6°N 130.0°E ±200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt
# TD expected upgrading
# Forecast 24 hr (0412UTC):
# Pressure 1000 hPa
# at 9.6 degree north 130.0 degree east
# with 200 km of 70 percent probability circle.
# Moving north-west 6 knots.
# Max winds 35 knots.
# Gust 50 knots.
# Expected to be TROPICAL STORM.
# http://www.jma.go.jp/en/typh/index.html
# TC_Number
# 1702
# TC_Remark
# Upgrading
# TC_Classification
# TS
# TC_MovingDirection
# NW
# TC_MovingSpeed
# 6 kt
# TC_CenterPressure
# 1000 hPa
# TC_Location
# ミンダナオ島の東
# TC_MaxSustainedWind
# 35 kt
# TC_PeakGust
# 50 kt
# EventEndTime
# 2017-02-04T12:00:00+00:00
# TC_AnalysisTime
# 2017-02-03T12:00:00+00:00
# UUID
# aed0d8b0-fa9b-308f-a693-cc158f12d8eb
# Sea East of Mindanao
# 9.6,130.0 200

# %%
data
# Out:
# [{'cap_alert': u'',
#   'cap_alert_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_area': u'',
#   'cap_area_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_areadesc': u'Sea East of Mindanao',
#   'cap_areadesc_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Sea East of Mindanao'},
#   'cap_category': u'Met',
#   'cap_category_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Met'},
#   'cap_certainty': u'Observed',
#   'cap_certainty_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Observed'},
#   'cap_circle': u'7.6,131.6 0',
#   'cap_circle_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'7.6,131.6 0'},
#   'cap_code': u'CAP-RSMCTK',
#   'cap_code_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'CAP-RSMCTK'},
#   'cap_description': u'TD expected upgrading\nANALYSIS (0312UTC):\nPressure 1004 hPa\nat 7.6 degree north 131.6 degree east\nposition POOR (radius more than 110 km).\nMoving west-north-west 9 knots.\nMax winds 30 knots.\nGust 45 knots.',
#   'cap_description_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TD expected upgrading\nANALYSIS (0312UTC):\nPressure 1004 hPa\nat 7.6 degree north 131.6 degree east\nposition POOR (radius more than 110 km).\nMoving west-north-west 9 knots.\nMax winds 30 knots.\nGust 45 knots.'},
#   'cap_effective': u'2017-02-03T13:10:00+00:00',
#   'cap_effective_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T13:10:00+00:00'},
#   'cap_event': u'TROPICAL CYCLONE ADVISORY/ANALYSIS',
#   'cap_event_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TROPICAL CYCLONE ADVISORY/ANALYSIS'},
#   'cap_eventcode': u'',
#   'cap_eventcode_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_expires': u'2017-02-03T19:30:00+00:00',
#   'cap_expires_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T19:30:00+00:00'},
#   'cap_headline': u'TD expected upgrading ANALYSIS (0312UTC): 7.6\xb0N 131.6\xb0E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt',
#   'cap_headline_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TD expected upgrading ANALYSIS (0312UTC): 7.6\xb0N 131.6\xb0E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt'},
#   'cap_identifier': u'urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941',
#   'cap_identifier_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941'},
#   'cap_info': u'',
#   'cap_info_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_language': u'en-US',
#   'cap_language_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'en-US'},
#   'cap_msgtype': u'Alert',
#   'cap_msgtype_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Alert'},
#   'cap_onset': u'2017-02-03T12:00:00+00:00',
#   'cap_onset_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T12:00:00+00:00'},
#   'cap_parameter': u'',
#   'cap_parameter_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_scope': u'Public',
#   'cap_scope_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Public'},
#   'cap_sender': u'rsmc-tokyo@met.kishou.go.jp',
#   'cap_sender_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'rsmc-tokyo@met.kishou.go.jp'},
#   'cap_sendername': u'RSMC Tokyo - Typhoon Center',
#   'cap_sendername_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'RSMC Tokyo - Typhoon Center'},
#   'cap_sent': u'2017-02-03T13:05:42+00:00',
#   'cap_sent_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T13:05:42+00:00'},
#   'cap_severity': u'Unknown',
#   'cap_severity_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Unknown'},
#   'cap_status': u'Actual',
#   'cap_status_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Actual'},
#   'cap_urgency': u'Unknown',
#   'cap_urgency_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Unknown'},
#   'cap_value': u'eb13a68c-97b3-3ba7-a967-9b4e93337941',
#   'cap_value_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'eb13a68c-97b3-3ba7-a967-9b4e93337941'},
#   'cap_valuename': u'UUID',
#   'cap_valuename_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'UUID'},
#   'cap_web': u'http://www.jma.go.jp/en/typh/index.html',
#   'cap_web_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'http://www.jma.go.jp/en/typh/index.html'},
#   'content': [{'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#     'language': None,
#     'type': u'application/cap+xml',
#     'value': u''}],
#   'guidislink': True,
#   'id': u'urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941',
#   'link': u'urn:uuid:eb13a68c-97b3-3ba7-a967-9b4e93337941',
#   'summary': u'<pre>TD expected upgrading\nANALYSIS (0312UTC):\nPressure 1004 hPa\nat 7.6 degree north 131.6 degree east\nposition POOR (radius more than 110 km).\nMoving west-north-west 9 knots.\nMax winds 30 knots.\nGust 45 knots.\n</pre>',
#   'summary_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/xhtml+xml',
#    'value': u'<pre>TD expected upgrading\nANALYSIS (0312UTC):\nPressure 1004 hPa\nat 7.6 degree north 131.6 degree east\nposition POOR (radius more than 110 km).\nMoving west-north-west 9 knots.\nMax winds 30 knots.\nGust 45 knots.\n</pre>'},
#   'title': u'TD expected upgrading ANALYSIS (0312UTC): 7.6\xb0N 131.6\xb0E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt',
#   'title_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'TD expected upgrading ANALYSIS (0312UTC): 7.6\xb0N 131.6\xb0E POOR MOVE WNW 9 kt PRES 1004 hPa MXWD 30 kt GUST 45 kt'},
#   'updated': u'2017-02-03T13:05:42.001Z',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=2, tm_mday=3, tm_hour=13, tm_min=5, tm_sec=42, tm_wday=4, tm_yday=34, tm_isdst=0)},
#  {'cap_alert': u'',
#   'cap_alert_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_area': u'',
#   'cap_area_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_areadesc': u'Sea East of Mindanao',
#   'cap_areadesc_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Sea East of Mindanao'},
#   'cap_category': u'Met',
#   'cap_category_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Met'},
#   'cap_certainty': u'Observed',
#   'cap_certainty_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Observed'},
#   'cap_circle': u'9.6,130.0 200',
#   'cap_circle_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'9.6,130.0 200'},
#   'cap_code': u'CAP-RSMCTK',
#   'cap_code_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'CAP-RSMCTK'},
#   'cap_description': u'TD expected upgrading\nForecast 24 hr (0412UTC):\nPressure 1000 hPa\nat 9.6 degree north 130.0 degree east\nwith 200 km of 70 percent probability circle.\nMoving north-west 6 knots.\nMax winds 35 knots.\nGust 50 knots.\nExpected to be TROPICAL STORM.',
#   'cap_description_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TD expected upgrading\nForecast 24 hr (0412UTC):\nPressure 1000 hPa\nat 9.6 degree north 130.0 degree east\nwith 200 km of 70 percent probability circle.\nMoving north-west 6 knots.\nMax winds 35 knots.\nGust 50 knots.\nExpected to be TROPICAL STORM.'},
#   'cap_effective': u'2017-02-03T13:10:00+00:00',
#   'cap_effective_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T13:10:00+00:00'},
#   'cap_event': u'TROPICAL CYCLONE ADVISORY/FORECAST',
#   'cap_event_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TROPICAL CYCLONE ADVISORY/FORECAST'},
#   'cap_eventcode': u'',
#   'cap_eventcode_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_expires': u'2017-02-03T19:30:00+00:00',
#   'cap_expires_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T19:30:00+00:00'},
#   'cap_headline': u'TD expected upgrading FCST 24h (0412UTC): 9.6\xb0N 130.0\xb0E \xb1200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt',
#   'cap_headline_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'TD expected upgrading FCST 24h (0412UTC): 9.6\xb0N 130.0\xb0E \xb1200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt'},
#   'cap_identifier': u'urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb',
#   'cap_identifier_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb'},
#   'cap_info': u'',
#   'cap_info_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_language': u'en-US',
#   'cap_language_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'en-US'},
#   'cap_msgtype': u'Alert',
#   'cap_msgtype_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Alert'},
#   'cap_onset': u'2017-02-04T12:00:00+00:00',
#   'cap_onset_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-04T12:00:00+00:00'},
#   'cap_parameter': u'',
#   'cap_parameter_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u''},
#   'cap_scope': u'Public',
#   'cap_scope_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Public'},
#   'cap_sender': u'rsmc-tokyo@met.kishou.go.jp',
#   'cap_sender_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'rsmc-tokyo@met.kishou.go.jp'},
#   'cap_sendername': u'RSMC Tokyo - Typhoon Center',
#   'cap_sendername_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'RSMC Tokyo - Typhoon Center'},
#   'cap_sent': u'2017-02-03T13:05:42+00:00',
#   'cap_sent_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'2017-02-03T13:05:42+00:00'},
#   'cap_severity': u'Unknown',
#   'cap_severity_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Unknown'},
#   'cap_status': u'Actual',
#   'cap_status_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Actual'},
#   'cap_urgency': u'Unknown',
#   'cap_urgency_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'Unknown'},
#   'cap_value': u'aed0d8b0-fa9b-308f-a693-cc158f12d8eb',
#   'cap_value_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'aed0d8b0-fa9b-308f-a693-cc158f12d8eb'},
#   'cap_valuename': u'UUID',
#   'cap_valuename_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'UUID'},
#   'cap_web': u'http://www.jma.go.jp/en/typh/index.html',
#   'cap_web_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/cap+xml',
#    'value': u'http://www.jma.go.jp/en/typh/index.html'},
#   'content': [{'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#     'language': None,
#     'type': u'application/cap+xml',
#     'value': u''}],
#   'guidislink': True,
#   'id': u'urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb',
#   'link': u'urn:uuid:aed0d8b0-fa9b-308f-a693-cc158f12d8eb',
#   'summary': u'<pre>TD expected upgrading\nForecast 24 hr (0412UTC):\nPressure 1000 hPa\nat 9.6 degree north 130.0 degree east\nwith 200 km of 70 percent probability circle.\nMoving north-west 6 knots.\nMax winds 35 knots.\nGust 50 knots.\nExpected to be TROPICAL STORM.\n</pre>',
#   'summary_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'application/xhtml+xml',
#    'value': u'<pre>TD expected upgrading\nForecast 24 hr (0412UTC):\nPressure 1000 hPa\nat 9.6 degree north 130.0 degree east\nwith 200 km of 70 percent probability circle.\nMoving north-west 6 knots.\nMax winds 35 knots.\nGust 50 knots.\nExpected to be TROPICAL STORM.\n</pre>'},
#   'title': u'TD expected upgrading FCST 24h (0412UTC): 9.6\xb0N 130.0\xb0E \xb1200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt',
#   'title_detail': {'base': u'http://www.data.jma.go.jp/fcd/yoho/cap-rsmctk/atom.xml',
#    'language': None,
#    'type': u'text/plain',
#    'value': u'TD expected upgrading FCST 24h (0412UTC): 9.6\xb0N 130.0\xb0E \xb1200 km MOVE NW 6 kt PRES 1000 hPa TOBE TS MXWD 35 kt GUST 50 kt'},
#   'updated': u'2017-02-03T13:05:42.002Z',
#   'updated_parsed': time.struct_time(tm_year=2017, tm_mon=2, tm_mday=3, tm_hour=13, tm_min=5, tm_sec=42, tm_wday=4, tm_yday=34, tm_isdst=0)}]

# %%
buls = len(data)

# %%
for b in range(buls):
    print (data[b].summary)
# Out:
# <pre>TD expected upgrading
# ANALYSIS (0312UTC):
# Pressure 1004 hPa
# at 7.6 degree north 131.6 degree east
# position POOR (radius more than 110 km).
# Moving west-north-west 9 knots.
# Max winds 30 knots.
# Gust 45 knots.
# </pre>
# <pre>TD expected upgrading
# Forecast 24 hr (0412UTC):
# Pressure 1000 hPa
# at 9.6 degree north 130.0 degree east
# with 200 km of 70 percent probability circle.
# Moving north-west 6 knots.
# Max winds 35 knots.
# Gust 50 knots.
# Expected to be TROPICAL STORM.
# </pre>
